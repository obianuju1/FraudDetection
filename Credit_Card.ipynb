# %% [markdown]
# <a href="https://colab.research.google.com/github/obianuju1/FraudDetection/blob/main/Credit_Card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# !kaggle datasets download -d mlg-ulb/creditcardfraud
# !unzip creditcardfraud.zip
# Out:
# mkdir: cannot create directory ‘/root/.kaggle’: File exists
# cp: cannot stat 'kaggle.json': No such file or directory
# chmod: cannot access '/root/.kaggle/kaggle.json': No such file or directory
# Dataset URL: https://www.kaggle.com/datasets/mlg-ulb/creditcardfraud
# License(s): DbCL-1.0
# creditcardfraud.zip: Skipping, found more recently modified local copy (use --force to force download)
# Archive:  creditcardfraud.zip
# replace creditcard.csv? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: creditcard.csv

# %%
import pandas as pd
df = pd.read_csv('creditcard.csv')
df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 0            0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388
# 1            0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361
# 2            1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499
# 3            1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203
# 4            2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921
# ...          ...       ...       ...       ...       ...       ...       ...
# 348060  160930.0  1.875754 -0.546235 -0.012430  0.299645 -0.745193  0.117545
# 348061  160930.0  1.920392  0.308281 -2.692298  1.054117  1.919784  1.101515
# 348062  160930.0 -4.340723  3.109247 -1.148444 -0.159526 -2.645835 -0.592827
# 348063  160930.0  1.585693 -1.029592 -1.540494  0.125769  0.006604  0.060928
# 348064  160930.0 -1.611418  1.659217 -0.977356 -0.746698 -0.183138 -0.636617
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 0       0.239599  0.098698  0.363787  ... -0.018307  0.277838 -0.110474
# 1      -0.078803  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288
# 2       0.791461  0.247676 -1.514654  ...  0.247998  0.771679  0.909412
# 3       0.237609  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321
# 4       0.592941 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458
# ...          ...       ...       ...  ...       ...       ...       ...
# 348060 -0.855484  0.160214  1.196884  ...  0.141402  0.551345  0.186820
# 348061  0.307974  0.271223 -0.046354  ...  0.037938  0.372764 -0.004101
# 348062 -2.261003  3.138933 -0.932311  ...  0.274750 -0.485363  0.080569
# 348063  0.153937 -0.044163  0.817159  ... -0.000736 -0.325880 -0.003948
# 348064  0.025867  0.839185 -0.328529  ...       NaN       NaN       NaN
#
#              V24       V25       V26       V27       V28  Amount  Class
# 0       0.066928  0.128539 -0.189115  0.133558 -0.021053  149.62    0.0
# 1      -0.339846  0.167170  0.125895 -0.008983  0.014724    2.69    0.0
# 2      -0.689281 -0.327642 -0.139097 -0.055353 -0.059752  378.66    0.0
# 3      -1.175575  0.647376 -0.221929  0.062723  0.061458  123.50    0.0
# 4       0.141267 -0.206010  0.502292  0.219422  0.215153   69.99    0.0
# ...          ...       ...       ...       ...       ...     ...    ...
# 348060 -0.382094 -0.371877 -0.409563  0.057220 -0.032903   36.40    0.0
# 348061 -1.077150  0.331907 -0.409093  0.039049 -0.050478    5.45    0.0
# 348062 -0.086778  0.416046 -0.487368 -1.820859 -0.515789   20.56    0.0
# 348063  0.316699 -0.122789 -0.137771 -0.073642 -0.023522  233.78    0.0
# 348064       NaN       NaN       NaN       NaN       NaN     NaN    NaN
#
# [348065 rows x 31 columns]

# %%
df['Class'].value_counts()
# Out:
# Class
# 0.0    286289
# 1.0       494
# Name: count, dtype: int64

# %%
df.hist()
# Out:
# array([[<Axes: title={'center': 'Time'}>, <Axes: title={'center': 'V1'}>,
#         <Axes: title={'center': 'V2'}>, <Axes: title={'center': 'V3'}>,
#         <Axes: title={'center': 'V4'}>, <Axes: title={'center': 'V5'}>],
#        [<Axes: title={'center': 'V6'}>, <Axes: title={'center': 'V7'}>,
#         <Axes: title={'center': 'V8'}>, <Axes: title={'center': 'V9'}>,
#         <Axes: title={'center': 'V10'}>, <Axes: title={'center': 'V11'}>],
#        [<Axes: title={'center': 'V12'}>, <Axes: title={'center': 'V13'}>,
#         <Axes: title={'center': 'V14'}>, <Axes: title={'center': 'V15'}>,
#         <Axes: title={'center': 'V16'}>, <Axes: title={'center': 'V17'}>],
#        [<Axes: title={'center': 'V18'}>, <Axes: title={'center': 'V19'}>,
#         <Axes: title={'center': 'V20'}>, <Axes: title={'center': 'V21'}>,
#         <Axes: title={'center': 'V22'}>, <Axes: title={'center': 'V23'}>],
#        [<Axes: title={'center': 'V24'}>, <Axes: title={'center': 'V25'}>,
#         <Axes: title={'center': 'V26'}>, <Axes: title={'center': 'V27'}>,
#         <Axes: title={'center': 'V28'}>,
#         <Axes: title={'center': 'Amount'}>],
#        [<Axes: title={'center': 'Class'}>, <Axes: >, <Axes: >, <Axes: >,
#         <Axes: >, <Axes: >]], dtype=object)

# %%
from sklearn.preprocessing import RobustScaler
new_df = df.copy()
new_df['Amount'] = RobustScaler().fit_transform(new_df['Amount'].to_numpy().reshape(-1,1))
time = new_df['Time']
new_df['Time'] = (time-time.min())/ (time.max() -time.min())
new_df
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 
# 21440   1.647511 -0.480963 -1.546866  ...  1.252092 -0.993085 -2.173147
# 117583 -0.463724  0.148857  0.785062  ... -0.143322 -0.479981 -0.237902
# 73349   0.205204  0.588754 -1.187820  ...  0.025147  0.086506 -0.262748
# 267336 -0.807534  0.202915  0.858635  ...  0.141950  0.358412  0.259748
# 128037  0.169413  0.074553  1.247988  ... -0.102350  0.323975 -0.172601
#
#              V24       V25       V26       V27       V28     Amount  Class
# 223456  0.683228 -0.973974  0.353528  0.305782 -0.250608   8.150580    0.0
# 219354  0.016404 -0.421416 -0.523685  0.095569  0.203610   4.464869    0.0
# 107570 -0.787730  0.684875  0.496356 -0.025745 -0.014006  -0.301299    0.0
# 193968  0.940558 -0.405827  0.139421 -0.067336 -0.050112  -0.279648    0.0
# 12569   0.006981  0.387459 -0.290555  0.148102 -0.041246   7.584858    0.0
# ...          ...       ...       ...       ...       ...        ...    ...
# 21440   0.145570 -0.235062 -0.227411 -0.382702  0.404045  31.991340    0.0
# 117583 -0.715247  0.251418  0.975406 -0.060168  0.023771   2.085766    0.0
# 73349   0.321538  0.341667  0.210343 -0.162047  0.031193  -0.201425    0.0
# 267336  0.746839 -0.560808  0.104636 -0.005853 -0.019622   1.016902    0.0
# 128037  0.126965 -0.001998 -0.398741 -0.385589 -0.205589   0.500070    0.0
#
# [286785 rows x 31 columns]

# %%
train, test, val = new_df[:240000], new_df[240000:269000], new_df[269000:]
train['Class'].value_counts(), test['Class'].value_counts(), val['Class'].value_counts()
# Out:
# (Class
#  0.0    239581
#  1.0       417
#  Name: count, dtype: int64,
#  Class
#  0.0    28947
#  1.0       53
#  Name: count, dtype: int64,
#  Class
#  0.0    17761
#  1.0       24
#  Name: count, dtype: int64)

# %%
train_np,test_np, val_np = train.to_numpy(), test.to_numpy(), val.to_numpy()
train_np.shape, test_np.shape,val_np.shape
# Out:
# ((240000, 31), (29000, 31), (17785, 31))

# %%
x_train, y_train = train_np[:,:-1], train_np[:,-1]
x_test, y_test = test_np[:,:-1], test_np[:,-1]
x_val, y_val = val_np[:,:-1], val_np[:,-1]

# %%
# Mask for rows with NaN values in either x_train or y_train
mask = ~(np.isnan(x_train).any(axis=1) | np.isnan(y_train))

# Apply the mask to both x_train and y_train
x_train = x_train[mask]
y_train = y_train[mask]

# Now you can proceed with fitting the model:
from sklearn.linear_model import LogisticRegression
logistic_model = LogisticRegression()
logistic_model.fit(x_train, y_train)
logistic_model.score(x_train, y_train)
# Out:
# 0.9992666605555046

# %%
from sklearn.metrics import classification_report
print(classification_report(y_val, logistic_model.predict(x_val),target_names=["Not Fraud","Fraud"]))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     17761
#        Fraud       0.82      0.58      0.68        24
#
#     accuracy                           1.00     17785
#    macro avg       0.91      0.79      0.84     17785
# weighted avg       1.00      1.00      1.00     17785

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import InputLayer, Dense, BatchNormalization
from tensorflow.keras.callbacks import ModelCheckpoint

shallow_nn = Sequential()
shallow_nn.add(InputLayer((x_train.shape[1],)))
shallow_nn.add(Dense(2, 'relu'))
shallow_nn.add(BatchNormalization())
shallow_nn.add(Dense(1, 'sigmoid'))

checkpoint = ModelCheckpoint('shallow_nn.keras', save_best_only=True)
shallow_nn.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
shallow_nn.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 2)                   │              62 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ batch_normalization_2                │ (None, 2)                   │               8 │
# │ (BatchNormalization)                 │                             │                 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 1)                   │               3 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 73 (292.00 B)
#  Trainable params: 69 (276.00 B)
#  Non-trainable params: 4 (16.00 B)

# %%
shallow_nn.fit(x_train, y_train, validation_data=(x_val, y_val), epochs=5, callbacks=checkpoint)
# Out:
# Epoch 1/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 16s 2ms/step - accuracy: 0.9612 - loss: 0.1704 - val_accuracy: 0.9985 - val_loss: 0.0097
# Epoch 2/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9984 - loss: 0.0104 - val_accuracy: 0.9988 - val_loss: 0.0069
# Epoch 3/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.9993 - loss: 0.0038 - val_accuracy: 0.9990 - val_loss: 0.0054
# Epoch 4/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 14s 2ms/step - accuracy: 0.9992 - loss: 0.0041 - val_accuracy: 0.9989 - val_loss: 0.0053
# Epoch 5/5
# 7500/7500 ━━━━━━━━━━━━━━━━━━━━ 20s 2ms/step - accuracy: 0.9992 - loss: 0.0036 - val_accuracy: 0.9990 - val_loss: 0.0061

# %%
def neural_net_predictions(model,x):
  return (shallow_nn.predict(x).flatten()>0.5).astype(int)
neural_net_predictions(shallow_nn,x_val)
# Out:
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# array([0, 0, 0, ..., 0, 0, 0])

# %%
print(classification_report(y_val, neural_net_predictions(shallow_nn,x_val),target_names=["Not Fraud","Fraud"]))
# Out:
# 556/556 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     17761
#        Fraud       0.63      0.71      0.67        24
#
#     accuracy                           1.00     17785
#    macro avg       0.81      0.85      0.83     17785
# weighted avg       1.00      1.00      1.00     17785

# %%
from sklearn.ensemble import RandomForestClassifier
random_forest = RandomForestClassifier(max_depth=2, n_jobs=-1)
random_forest.fit(x_train, y_train)
print(classification_report(y_val, random_forest.predict(x_val),target_names=["Not Fraud","Fraud"]))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     17761
#        Fraud       0.79      0.46      0.58        24
#
#     accuracy                           1.00     17785
#    macro avg       0.89      0.73      0.79     17785
# weighted avg       1.00      1.00      1.00     17785

# %%
from sklearn.ensemble import GradientBoostingClassifier
gbc = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=1, random_state=0)
gbc.fit(x_train, y_train)
print(classification_report(y_val, gbc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      1.00      1.00     17761
#        Fraud       0.54      0.54      0.54        24
#
#     accuracy                           1.00     17785
#    macro avg       0.77      0.77      0.77     17785
# weighted avg       1.00      1.00      1.00     17785

# %%
from sklearn.svm import LinearSVC
svc = LinearSVC(class_weight='balanced')
svc.fit(x_train, y_train)
print(classification_report(y_val, svc.predict(x_val), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       1.00      0.98      0.99     17761
#        Fraud       0.07      0.96      0.12        24
#
#     accuracy                           0.98     17785
#    macro avg       0.53      0.97      0.56     17785
# weighted avg       1.00      0.98      0.99     17785

# %%
train.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 223456  0.168014 -3.617635 -3.937373 -2.520724  4.691156  3.716206  3.557139
# 219354  0.166031 -0.584945 -1.063530  0.340218 -2.941822 -1.051079  0.393030
# 107570  0.082608  1.275947 -0.118024  0.125415  0.505133 -0.080323  0.370960
# 193968  0.152769  1.999368 -0.001795 -0.683852  0.622857 -0.548182 -1.716422
# 12569   0.025802 -1.126878  0.480564  0.670173  1.028863 -1.787472  1.171225
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 223456  0.023641  1.448145 -2.353127  ...  1.091293  0.775113  1.467165
# 219354  1.169991 -0.148053 -0.144532  ... -0.343025 -0.957973  0.803397
# 107570 -0.325548  0.170264  0.569891  ... -0.127399 -0.176518 -0.229130
# 193968  0.227494 -0.411894  0.427950  ... -0.226507 -0.506514  0.446203
# 12569   3.109558 -0.433905  0.761034  ... -0.102986  0.070781  0.124547
#
#              V24       V25       V26       V27       V28    Amount  Class
# 223456  0.683228 -0.973974  0.353528  0.305782 -0.250608  8.150580    0.0
# 219354  0.016404 -0.421416 -0.523685  0.095569  0.203610  4.464869    0.0
# 107570 -0.787730  0.684875  0.496356 -0.025745 -0.014006 -0.301299    0.0
# 193968  0.940558 -0.405827  0.139421 -0.067336 -0.050112 -0.279648    0.0
# 12569   0.006981  0.387459 -0.290555  0.148102 -0.041246  7.584858    0.0
#
# [5 rows x 31 columns]

# %%
not_frauds = new_df.query('Class == 0')
frauds = new_df.query('Class == 1')
not_frauds['Class'].value_counts(), frauds['Class'].value_counts()
# Out:
# (Class
#  0.0    286289
#  Name: count, dtype: int64,
#  Class
#  1.0    494
#  Name: count, dtype: int64)

# %%
balanced_df = pd.concat([frauds, not_frauds.sample(len(frauds), random_state=1)])
balanced_df['Class'].value_counts()
# Out:
# Class
# 1.0    494
# 0.0    494
# Name: count, dtype: int64

# %%
balanced_df = balanced_df.sample(frac=1, random_state=1)
balanced_df
# Out:
#             Time         V1         V2         V3         V4         V5  \
# 72425   0.064096  -0.093598   0.945955   0.572563  -0.514023   0.797301
# 191359  0.151411   1.177824   2.487103  -5.330608   5.324547   1.150243
# 129487  0.092691   1.216616  -1.453622   0.545910  -1.282764  -1.674065
# 15736   0.031827 -23.914101  13.765942 -25.733734   6.290918 -17.784824
# 88901   0.073047   1.245331   0.037340  -0.611091   0.587214   0.403674
# ...          ...        ...        ...        ...        ...        ...
# 28134   0.040856   1.473389  -0.245361  -0.080424  -0.798437  -0.475515
# 83417   0.070115  -3.215382  -0.364223  -1.261883   3.794949   0.711206
# 6739    0.009914   1.151700  -0.011932   1.170528   1.134889  -0.707808
# 151011  0.110568 -15.192064  10.432528 -19.629515   8.046075 -12.838167
# 150677  0.109999 -13.086519   7.352148 -18.256576  10.648505 -11.731476
#
#               V6         V7         V8        V9  ...       V21       V22  \
# 72425  -0.741257   0.846012  -0.179607 -0.385460  ... -0.136701 -0.374818
# 191359 -1.281843  -1.171994   0.413778 -2.659840  ...  0.262325 -0.431790
# 129487 -0.405780  -1.006064  -0.055249 -1.719839  ... -0.268174 -0.683391
# 15736  -4.572498 -17.390764  15.794136 -3.819832  ...  1.773399 -1.748426
# 88901   0.492230  -0.253933   0.203755  0.580380  ... -0.242090 -0.564378
# ...          ...        ...        ...       ...  ...       ...       ...
# 28134  -1.015297  -0.118768  -0.333267 -1.129732  ... -0.232465 -0.766607
# 83417  -1.316476  -5.165141   0.625278 -1.582301  ...  0.401341  0.152191
# 6739   -0.002691  -0.506230   0.002535  2.141613  ... -0.243020 -0.034244
# 151011 -1.875859 -21.359738  -3.717850 -5.969782  ... -3.474097  1.765446
# 150677 -3.659167 -14.873658   8.810473 -5.418204  ...  2.761157 -0.266162
#
#              V23       V24       V25       V26       V27       V28    Amount  \
# 72425   0.107053 -0.491040 -1.132871 -0.214319  0.198383  0.241211 -0.289286
# 191359 -0.092088  0.145216  0.457788  0.167739  0.451243  0.268421 -0.239279
# 129487  0.101744  0.027952  0.004084 -0.393218  0.034138  0.047791  1.629418
# 15736  -1.093104  0.147807  1.663792 -0.221024  1.458076  0.430315  1.089398
# 88901  -0.325942 -1.483442  0.711412  0.502327 -0.013715  0.016411  0.105601
# ...          ...       ...       ...       ...       ...       ...       ...
# 28134   0.063888 -0.130132  0.435184 -0.500152 -0.012168  0.009734 -0.195558
# 83417  -0.934675 -0.256148 -0.469403 -0.282496  0.866077 -0.433466 -0.224752
# 6739    0.016981  0.427332  0.397987  0.497480 -0.009027  0.006888 -0.307166
# 151011  1.701257  0.381587 -1.413417 -1.023078 -2.634761 -0.463931 -0.293337
# 150677 -0.412861  0.519952 -0.743909 -0.167808 -2.498300 -0.711066  0.116078
#
#         Class
# 72425     0.0
# 191359    1.0
# 129487    0.0
# 15736     1.0
# 88901     0.0
# ...       ...
# 28134     0.0
# 83417     1.0
# 6739      0.0
# 151011    1.0
# 150677    1.0
#
# [988 rows x 31 columns]

# %%
balanced_df_np = balanced_df.to_numpy()

x_train_b, y_train_b = balanced_df_np[:700, :-1], balanced_df_np[:700, -1].astype(int)
x_test_b, y_test_b = balanced_df_np[700:842, :-1], balanced_df_np[700:842, -1].astype(int)
x_val_b, y_val_b = balanced_df_np[842:, :-1], balanced_df_np[842:, -1].astype(int)
x_train_b.shape, y_train_b.shape, x_test_b.shape, y_test_b.shape, x_val_b.shape, y_val_b.shape
# Out:
# ((700, 30), (700,), (142, 30), (142,), (146, 30), (146,))

# %%
pd.Series(y_train_b).value_counts(), pd.Series(y_test_b).value_counts(), pd.Series(y_val_b).value_counts()
# Out:
# (1    353
#  0    347
#  Name: count, dtype: int64,
#  0    73
#  1    69
#  Name: count, dtype: int64,
#  0    74
#  1    72
#  Name: count, dtype: int64)

# %%
logistic_model_b = LogisticRegression()
logistic_model_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, logistic_model_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.86      0.97      0.91        74
#        Fraud       0.97      0.83      0.90        72
#
#     accuracy                           0.90       146
#    macro avg       0.91      0.90      0.90       146
# weighted avg       0.91      0.90      0.90       146

# %%
shallow_nn_b = Sequential()
shallow_nn_b.add(InputLayer((x_train.shape[1],)))
shallow_nn_b.add(Dense(2, 'relu'))
shallow_nn_b.add(BatchNormalization())
shallow_nn_b.add(Dense(1, 'sigmoid'))

checkpoint = ModelCheckpoint('shallow_nn_b.keras', save_best_only=True)
shallow_nn_b.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
shallow_nn_b.fit(x_train_b, y_train_b, validation_data=(x_val_b, y_val_b), epochs=40, callbacks=checkpoint)
# Out:
# Epoch 1/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.6421 - loss: 0.6420 - val_accuracy: 0.6233 - val_loss: 0.6180
# Epoch 2/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7308 - loss: 0.5519 - val_accuracy: 0.6918 - val_loss: 0.5573
# Epoch 3/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.
40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9478 - loss: 0.1381 - val_accuracy: 0.9041 - val_loss: 0.2927
# Epoch 26/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9440 - loss: 0.1531 - val_accuracy: 0.9041 - val_loss: 0.2926
# Epoch 27/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9579 - loss: 0.1382 - val_accuracy: 0.9041 - val_loss: 0.2945
# Epoch 28/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9642 - loss: 0.1261 - val_accuracy: 0.9041 - val_loss: 0.2984
# Epoch 29/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9565 - loss: 0.1381 - val_accuracy: 0.9041 - val_loss: 0.2967
# Epoch 30/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9569 - loss: 0.1355 - val_accuracy: 0.9041 - val_loss: 0.2985
# Epoch 31/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9530 - loss: 0.1375 - val_accuracy: 0.9041 - val_loss: 0.2996
# Epoch 32/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9461 - loss: 0.1478 - val_accuracy: 0.9041 - val_loss: 0.3010
# Epoch 33/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9633 - loss: 0.1403 - val_accuracy: 0.9041 - val_loss: 0.3000
# Epoch 34/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9397 - loss: 0.1538 - val_accuracy: 0.9041 - val_loss: 0.3024
# Epoch 35/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.1602 - val_accuracy: 0.9041 - val_loss: 0.3039
# Epoch 36/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9325 - loss: 0.1711 - val_accuracy: 0.9041 - val_loss: 0.3044
# Epoch 37/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9430 - loss: 0.1626 - val_accuracy: 0.9041 - val_loss: 0.3053
# Epoch 38/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9428 - loss: 0.1473 - val_accuracy: 0.9041 - val_loss: 0.3076
# Epoch 39/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9497 - loss: 0.1571 - val_accuracy: 0.9041 - val_loss: 0.3093
# Epoch 40/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9594 - loss: 0.1310 - val_accuracy: 0.9041 - val_loss: 0.3095

# %%
print(classification_report(y_val_b, neural_net_predictions(shallow_nn_b, x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       0.81      1.00      0.90        74
#        Fraud       1.00      0.76      0.87        72
#
#     accuracy                           0.88       146
#    macro avg       0.91      0.88      0.88       146
# weighted avg       0.91      0.88      0.88       146

# %%
shallow_nn_b1 = Sequential()
shallow_nn_b1.add(InputLayer((x_train.shape[1],)))
shallow_nn_b1.add(Dense(1, 'relu'))
shallow_nn_b1.add(BatchNormalization())
shallow_nn_b1.add(Dense(1, 'sigmoid'))

checkpoint = ModelCheckpoint('shallow_nn_b1.keras', save_best_only=True)
shallow_nn_b1.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
shallow_nn_b1.fit(x_train_b, y_train_b, validation_data=(x_val_b, y_val_b), epochs=40, callbacks=checkpoint)
# Out:
# Epoch 1/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 4s 12ms/step - accuracy: 0.6767 - loss: 0.6757 - val_accuracy: 0.6986 - val_loss: 0.6438
# Epoch 2/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.7907 - loss: 0.6592 - val_accuracy: 0.7397 - val_loss: 0.6204
# Epoch 3/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8280 - loss: 0.6456 - val_accuracy: 0.8219 - val_loss: 0.6068
# Epoch 4/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8555 - loss: 0.6352 - val_accuracy: 0.8493 - val_loss: 0.5960
# Epoch 5/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8665 - loss: 0.6236 - val_accuracy: 0.8767 - val_loss: 0.5861
# Epoch 6/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8676 - loss: 0.6147 - val_accuracy: 0.8904 - val_loss: 0.5770
# Epoch 7/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8720 - loss: 0.6015 - val_accuracy: 0.8904 - val_loss: 0.5684
# Epoch 8/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.
40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9212 - loss: 0.3070 - val_accuracy: 0.9041 - val_loss: 0.3372

# %%
shallow_nn_b1.fit(x_train_b, y_train_b, validation_data=(x_val_b, y_val_b), epochs=40, callbacks=checkpoint)
# Out:
# Epoch 1/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9280 - loss: 0.2953 - val_accuracy: 0.9041 - val_loss: 0.3347
# Epoch 2/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.2932 - val_accuracy: 0.9041 - val_loss: 0.3298
# Epoch 3/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9172 - loss: 0.2851 - val_accuracy: 0.9110 - val_loss: 0.3255
# Epoch 4/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9330 - loss: 0.2750 - val_accuracy: 0.9041 - val_loss: 0.3262
# Epoch 5/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9272 - loss: 0.2705 - val_accuracy: 0.9041 - val_loss: 0.3237
# Epoch 6/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9162 - loss: 0.2748 - val_accuracy: 0.9110 - val_loss: 0.3185
# Epoch 7/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9476 - loss: 0.2566 - val_accuracy: 0.9041 - val_loss: 0.3191
# Epoch 8/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9231 - loss: 0.2656 - val_accuracy: 0.9041 - val_loss: 0.3173
# Epoch 9/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9368 - loss: 0.2760 - val_accuracy: 0.9041 - val_loss: 0.3172
# Epoch 10/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9319 - loss: 0.2534 - val_accuracy: 0.9041 - val_loss: 0.3131
# Epoch 11/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9338 - loss: 0.2445 - val_accuracy: 0.9110 - val_loss: 0.3123
# Epoch 12/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9404 - loss: 0.2354 - val_accuracy: 0.9110 - val_loss: 0.3095
# Epoch 13/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9255 - loss: 0.2408 - val_accuracy: 0.9110 - val_loss: 0.3100
# Epoch 14/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step - accuracy: 0.9361 - loss: 0.2354 - val_accuracy: 0.9041 - val_loss: 0.3089
# Epoch 15/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.9297 - loss: 0.2358 - val_accuracy: 0.9041 - val_loss: 0.3072
# Epoch 16/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step - accuracy: 0.9134 - loss: 0.2557 - val_accuracy: 0.9041 - val_loss: 0.3039
# Epoch 17/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.9388 - loss: 0.2352 - val_accuracy: 0.9041 - val_loss: 0.3048
# Epoch 18/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9327 - loss: 0.2478 - val_accuracy: 0.9041 - val_loss: 0.3021
# Epoch 19/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9298 - loss: 0.2277 - val_accuracy: 0.9041 - val_loss: 0.3028
# Epoch 20/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9301 - loss: 0.2360 - val_accuracy: 0.9041 - val_loss: 0.3029
# Epoch 21/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9269 - loss: 0.2335 - val_accuracy: 0.9041 - val_loss: 0.3011
# Epoch 22/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9488 - loss: 0.2257 - val_accuracy: 0.9041 - val_loss: 0.3028
# Epoch 23/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.9251 - loss: 0.2216 - val_accuracy: 0.9041 - val_loss: 0.3027
# Epoch 24/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9443 - loss: 0.2136 - val_accuracy: 0.9041 - val_loss: 0.3014
# Epoch 25/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9277 - loss: 0.2151 - val_accuracy: 0.9041 - val_loss: 0.3006
# Epoch 26/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9249 - loss: 0.2223 - val_accuracy: 0.9041 - val_loss: 0.2981
# Epoch 27/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9330 - loss: 0.2060 - val_accuracy: 0.9041 - val_loss: 0.3012
# Epoch 28/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9410 - loss: 0.2107 - val_accuracy: 0.9041 - val_loss: 0.2988
# Epoch 29/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9310 - loss: 0.2105 - val_accuracy: 0.9041 - val_loss: 0.2971
# Epoch 30/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step - accuracy: 0.9287 - loss: 0.2263 - val_accuracy: 0.9041 - val_loss: 0.2970
# Epoch 31/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9294 - loss: 0.2157 - val_accuracy: 0.9041 - val_loss: 0.2977
# Epoch 32/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9376 - loss: 0.2218 - val_accuracy: 0.9041 - val_loss: 0.2931
# Epoch 33/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9429 - loss: 0.2084 - val_accuracy: 0.9041 - val_loss: 0.2980
# Epoch 34/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9380 - loss: 0.2021 - val_accuracy: 0.9041 - val_loss: 0.2994
# Epoch 35/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9262 - loss: 0.2003 - val_accuracy: 0.9041 - val_loss: 0.2991
# Epoch 36/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9416 - loss: 0.1750 - val_accuracy: 0.9041 - val_loss: 0.2973
# Epoch 37/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9292 - loss: 0.2106 - val_accuracy: 0.9041 - val_loss: 0.2987
# Epoch 38/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9240 - loss: 0.2158 - val_accuracy: 0.9041 - val_loss: 0.2983
# Epoch 39/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9329 - loss: 0.2102 - val_accuracy: 0.9041 - val_loss: 0.2975
# Epoch 40/40
# 22/22 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9425 - loss: 0.1894 - val_accuracy: 0.9041 - val_loss: 0.2963

# %%
print(classification_report(y_val_b, neural_net_predictions(shallow_nn_b1, x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       0.81      1.00      0.90        74
#        Fraud       1.00      0.76      0.87        72
#
#     accuracy                           0.88       146
#    macro avg       0.91      0.88      0.88       146
# weighted avg       0.91      0.88      0.88       146

# %%
rf_b = RandomForestClassifier(max_depth=2, n_jobs=-1)
rf_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, rf_b.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.85      0.97      0.91        74
#        Fraud       0.97      0.82      0.89        72
#
#     accuracy                           0.90       146
#    macro avg       0.91      0.90      0.90       146
# weighted avg       0.91      0.90      0.90       146

# %%
gbc_b = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0, max_depth=2, random_state=0)
gbc_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, gbc.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.75      1.00      0.86        74
#        Fraud       1.00      0.65      0.79        72
#
#     accuracy                           0.83       146
#    macro avg       0.87      0.83      0.82       146
# weighted avg       0.87      0.83      0.82       146

# %%
svc_b = LinearSVC(class_weight='balanced')
svc_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, svc.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.86      0.99      0.92        74
#        Fraud       0.98      0.83      0.90        72
#
#     accuracy                           0.91       146
#    macro avg       0.92      0.91      0.91       146
# weighted avg       0.92      0.91      0.91       146

# %%
svc_b = LinearSVC(class_weight='balanced')
svc_b.fit(x_train_b, y_train_b)
print(classification_report(y_val_b, svc.predict(x_val_b), target_names=['Not Fraud', 'Fraud']))
# Out:
#               precision    recall  f1-score   support
#
#    Not Fraud       0.86      0.99      0.92        74
#        Fraud       0.98      0.83      0.90        72
#
#     accuracy                           0.91       146
#    macro avg       0.92      0.91      0.91       146
# weighted avg       0.92      0.91      0.91       146

# %%
print(classification_report(y_test_b, neural_net_predictions(shallow_nn_b, x_test_b), target_names=['Not Fraud', 'Fraud']))
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
#               precision    recall  f1-score   support
#
#    Not Fraud       0.86      1.00      0.92        73
#        Fraud       1.00      0.83      0.90        69
#
#     accuracy                           0.92       142
#    macro avg       0.93      0.91      0.91       142
# weighted avg       0.93      0.92      0.91       142
